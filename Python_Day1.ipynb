# %% [markdown]
# <a href="https://colab.research.google.com/github/aurangzaib98/Python/blob/main/Python_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print('I am Aurang Zaib')
# Out:
# I am Aurang Zaib

# %%
print(type(3.14))
# Out:
# <class 'float'>

# %%
print(type("3.14"))
# Out:
# <class 'str'>

# %%
print("3.14"*2)
# Out:
# 3.143.14

# %%
print(3.14*2)
# Out:
# 6.28

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")
print()
print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print('My father\'s fav car is bmw')
# Out:
# My father's fav car is bmw

# %%
print('She said: "Python is fun!"')
# Out:
# She said: "Python is fun!"

# %%
print("C:\\new_folder\\test.txt")
# Out:
# C:\new_folder\test.txt

# %%
print("My name is Python. Monty Python.")
# Out:
# My name is Python. Monty Python.

# %%
print("hi",4435)
# Out:
# hi 4435

# %%
print("Hi." + "My name is Yusuf." + "I am learning Python.")
# Out:
# Hi.My name is Yusuf.I am learning Python.

# %%
# Python program to add two numbers

# Take input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Add the two numbers
sum_result = num1 + num2

# Display the sum
print("The sum of", num1, "and", num2, "is:", sum_result)
# Out:
# Enter the first number: 1
# Enter the second number: 2
# The sum of 1.0 and 2.0 is: 3.0

# %% [markdown]
# # Arithmetic Operators

# %%
print(20+4)
# Out:
# 24

# %%
print(20/4)
# Out:
# 5.0

# %%
print(20*2)
# Out:
# 40

# %%
print(20-12)
# Out:
# 8

# %%
print(20//3)
# Out:
# 6

# %%
print(20%3)
# Out:
# 2

# %%
print(20**5)
# Out:
# 3200000

# %%
# Number
number = 100

# Calculate square root using arithmetic operator
squareroot = number ** 0.5

# Print the result
print("The square root of", number, "is:", squareroot)
# Out:
# The square root of 100 is: 10.0

# %%
# Numbers
a = 17
b = 4

# Floor division
result = a // b

# Print the result
print("Floor division:", result)
# Out:
# Floor division: 4

# %%
# Numbers
a = 17
b = 4

# Calculate remainder
remainder = a % b

# Print the result
print("Result:", remainder)
# Out:
# Result: 1

# %%
my_age = 10
your_age = 12
my_age=your_age
print(my_age)
# Out:
# 12

# %%
# Step 1: Create a variable myName and assign your name
myName = "Aurang"

# Step 2: Print the variable
print("Name:", myName)

# Step 3: Check the type
print("Type:", type(myName))

# Step 4: Print length
print("Length:", len(myName))
# Out:
# Name: Aurang
# Type: <class 'str'>
# Length: 6

# %%
myname = "aurang"
print(myname)
# Out:
# aurang

# %% [markdown]
# Input Funtion

# %%
print("Tell me anything")

anything = input()

print("Hmm", anything, "interesting.")
# Out:
# Tell me anything
# hehe
# Hmm hehe interesting.

# %%
print("This is simple calculator")

number1 = input("Enter first number:")

number2 = input("Enter second number:")

result = number1 + number2

print(result)
# Out:
# This is simple calculator
# Enter first number:12
# Enter second number:8
# 12 + 8 = 128

# %%
print("This is a simple calculator")

# Get input from user and convert to numbers
number1 = float(input("Enter first number: "))
number2 = float(input("Enter second number: "))

# Perform addition
result = number1 + number2

# Print the result
print("The sum of", number1, "and", number2, "is:", result)
# Out:
# This is a simple calculator
# Enter first number: 5
# Enter second number: 7
# The sum of 5.0 and 7.0 is: 12.0

# %% [markdown]
# Type Casting

# %%
myage="27"
print(type(my_age))
# Out:
# <class 'int'>
# 12

# %%
myage="27"
print(int(myage))
# Out:
# 27

# %%
myage="27"
print(float(myage))
# Out:
# 27.0

# %%
time_hour = float(input("Tell me time in hours. I will calcaulate in seconds."))
print("Time in seconds is", time_hour*60*60)
# Out:
# Tell me time in hours. I will calcaulate in seconds.2
# Time in seconds is 7200.0
